# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
mydata = ('Boat', 'car', 'bike', 'truck')
myseries1 = pd.Series(mydata)

# %%
print(myseries1)
# Out:
# 0     Boat
# 1      car
# 2     bike
# 3    truck
# dtype: object

# %%
mydata = (55,99,1,43)
myseries2 = pd.Series(mydata)
print(myseries2)
# Out:
# 0    55
# 1    99
# 2     1
# 3    43
# dtype: int64

# %%
mydfdata = [('Boat', 1), ('car',99), ('bike',43), ('truck',24)]
mydf = pd.DataFrame(mydfdata, columns=['thing', 'count'])
mydf
# Out:
#    thing  count
# 0   Boat      1
# 1    car     99
# 2   bike     43
# 3  truck     24

# %%
mydf.dtypes
# Out:
# thing    object
# count     int64
# dtype: object

# %%
df = pd.read_csv('../input/crop-recommendation-dataset/Crop_recommendation.csv')

# %%
df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
df.tail()
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee

# %%
df.dtypes
# Out:
# N                int64
# P                int64
# K                int64
# temperature    float64
# humidity       float64
# ph             float64
# rainfall       float64
# label           object
# dtype: object

# %%
df.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
df['temperature']
# Out:
# 0       20.879744
# 1       21.770462
# 2       23.004459
# 3       26.491096
# 4       20.130175
#           ...
# 2195    26.774637
# 2196    27.417112
# 2197    24.131797
# 2198    26.272418
# 2199    23.603016
# Name: temperature, Length: 2200, dtype: float64

# %%
df.loc[123]
# Out:
# N                     83
# P                     45
# K                     21
# temperature    18.833445
# humidity        58.75082
# ph              5.716223
# rainfall        79.75329
# label              maize
# Name: 123, dtype: object

# %%
df[['N', 'P', 'K', 'temperature', 'humidity',
    'ph', 'rainfall', 'label']]
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
df.shape
# Out:
# (2200, 8)

# %%
df.loc[df['humidity']>80]
# Out:
#        N   P   K  temperature   humidity        ph    rainfall label
# 0     90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1     85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2     60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3     74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4     78  42  42    20.130175  81.604873  7.628473  262.717340  rice
# ...   ..  ..  ..          ...        ...       ...         ...   ...
# 2094  93  43  38    23.614753  86.142903  6.987333  150.235524  jute
# 2095  87  44  43    23.874845  86.792613  6.718725  177.514731  jute
# 2096  88  52  39    23.928879  88.071123  6.880205  154.660874  jute
# 2097  90  39  37    24.814412  81.686889  6.861069  190.788639  jute
# 2098  90  39  43    24.447439  82.286484  6.769346  190.968489  jute
#
# [1150 rows x 8 columns]

# %%
df.query('humidity <60')
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 103    73  58  21    19.972160  57.682729  6.596061   60.651715   maize
# 105    68  41  16    21.776893  57.808406  6.158831  102.086169   maize
# 112    62  52  16    22.275267  58.840159  6.967058   63.870206   maize
# 115    63  58  22    18.254054  55.282204  6.204748   63.723582   maize
# 123    83  45  21    18.833445  58.750820  5.716223   79.753290   maize
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2192  106  21  35    25.627355  57.041511  7.428524  188.550654  coffee
# 2193  116  38  34    23.292503  50.045570  6.020947  183.468585  coffee
# 2194   97  35  26    24.914610  53.741447  6.334610  166.254931  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
#
# [540 rows x 8 columns]

# %%
df.loc[~df['ph'].isna()]
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
df['humidity_to_temprature_ratio'] = df['humidity']/df['temperature']

# %%
df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label  \
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice
#
#    humidity_to_temprature_ratio
# 0                      3.927383
# 1                      3.689386
# 2                      3.578470
# 3                      3.025861
# 4                      4.053858

# %%
df['N'].plot(kind='hist',bins= 100)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['N'].plot(kind='hist', bins= 100,
            title = 'Distribution of Nitrogen Percentage',
            figsize=(15,5))
# Out:
# <Axes: title={'center': 'Distribution of Nitrogen Percentage'}, ylabel='Frequency'>

# %%
df.plot(kind= 'scatter', x='N', y='humidity',title = 'Nitrogen percentage in soild Vs Humididty')
# Out:
# <Axes: title={'center': 'Nitrogen percentage in soild Vs Humididty'}, xlabel='N', ylabel='humidity'>

# %%
df.to_csv('processed_data.csv')

# %%
df['P'].plot(kind='hist', bins= 100,
            title = 'Distribution of Phosphours Percentage',
            figsize=(15,5))
# Out:
# <Axes: title={'center': 'Distribution of Phosphours Percentage'}, ylabel='Frequency'>

# %%
df['K'].plot(kind='hist', bins= 100,
            title = 'Distribution of Potassium Percentage',
            figsize=(15,5))
# Out:
# <Axes: title={'center': 'Distribution of Potassium Percentage'}, ylabel='Frequency'>

# %%
df.plot(kind= 'scatter', x='P', y='humidity',title = 'Phosphorus percentage in soild Vs Humididty',c='green')
# Out:
# <Axes: title={'center': 'Phosphorus percentage in soild Vs Humididty'}, xlabel='P', ylabel='humidity'>

# %%
df.plot(kind= 'scatter', x='K', y='humidity',title = 'Potassium percentage in soild Vs Humididty',c='green')
# Out:
# <Axes: title={'center': 'Potassium percentage in soild Vs Humididty'}, xlabel='K', ylabel='humidity'>

# %%
df.plot(kind= 'scatter', x='rainfall', y='humidity',title = 'Rain Vs Humididty',c='green')
# Out:
# <Axes: title={'center': 'Rain Vs Humididty'}, xlabel='rainfall', ylabel='humidity'>

# %%
df.plot(kind= 'scatter', x='ph', y='rainfall',title = 'Corrilation between rainfall and pH',c='green')
# Out:
# <Axes: title={'center': 'Corrilation between rainfall and pH'}, xlabel='ph', ylabel='rainfall'>

# %%
sns.violinplot(x='humidity_to_temprature_ratio', y='rainfall', data=df, title= 'Rainfalls impact on Humidity and Temprature"s',c='green')
# Out:
# <Axes: xlabel='humidity_to_temprature_ratio', ylabel='rainfall'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   N                             2200 non-null   int64
#  1   P                             2200 non-null   int64
#  2   K                             2200 non-null   int64
#  3   temperature                   2200 non-null   float64
#  4   humidity                      2200 non-null   float64
#  5   ph                            2200 non-null   float64
#  6   rainfall                      2200 non-null   float64
#  7   label                         2200 non-null   object
#  8   humidity_to_temprature_ratio  2200 non-null   float64
# dtypes: float64(5), int64(3), object(1)
# memory usage: 154.8+ KB

# %%
df['label'].unique()
# Out:
# array(['rice', 'maize', 'chickpea', 'kidneybeans', 'pigeonpeas',
#        'mothbeans', 'mungbean', 'blackgram', 'lentil', 'pomegranate',
#        'banana', 'mango', 'grapes', 'watermelon', 'muskmelon', 'apple',
#        'orange', 'papaya', 'coconut', 'cotton', 'jute', 'coffee'],
#       dtype=object)

# %%
#Finding the diffrent possible number of combinations

# %%
import matplotlib.pyplot as plt

def fact(num):
    if num < 2:
        return 1
    return fact(num-1)*num
combinations = fact(7)/(fact(2)*fact(5))
combinations
# Out:
# 21.0

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df.drop('label',axis='columns'),figsize=(16,16),marker='.',alpha=0.4,c='green')
plt.show()

# %%
#it can also br analysised as Phosphorus levels exhibit noticeable variations during instances of heavy rainfall, particularly when the precipitation exceeds 150 mm

# %%
sns.boxplot(y='label',x='P',data=df[df['rainfall']>150])
# Out:
# <Axes: xlabel='P', ylabel='label'>

# %%
sns.boxplot(y='label',x='N',data=df[df['rainfall']>150])
# Out:
# <Axes: xlabel='N', ylabel='label'>

# %%
sns.boxplot(y='label',x='K',data=df[df['rainfall']>150])
# Out:
# <Axes: xlabel='K', ylabel='label'>

# %%
sns.lineplot(data = df[(df['humidity']<65)], x = "K", y = "rainfall",hue="label")
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
sns.jointplot(x="rainfall",y="humidity",data=df[(df['temperature']<30) & (df['rainfall']>120)],hue="label")
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
plt.figure(figsize=(12,5))
plt.subplot(1, 2, 1)
# sns.distplot(df_setosa['sepal_length'],kde=True,color='green',bins=20,hist_kws={'alpha':0.3})
sns.distplot(df['temperature'],color="purple",bins=15,hist_kws={'alpha':0.2})
plt.subplot(1, 2, 2)
sns.distplot(df['ph'],color="green",bins=15,hist_kws={'alpha':0.2})
# Out:
# /tmp/ipykernel_34/277399785.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['temperature'],color="purple",bins=15,hist_kws={'alpha':0.2})
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /tmp/ipykernel_34/277399785.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# ...
